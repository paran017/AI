# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/weather.csv")
df
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2     11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3     11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4     11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# ..          ...       ...      ...      ...       ...          ...       ...
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df = df.drop(columns=["RainTomorrow"])

# %%
df.isnull().sum()
# Out:
# Date              0
# Location          0
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RISK_MM          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for column in df.columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
y = df['Rainfall']
y
# Out:
# 0       0
# 1      16
# 2      16
# 3      43
# 4      13
#        ..
# 361     0
# 362     0
# 363     0
# 364     0
# 365     0
# Name: Rainfall, Length: 328, dtype: int64

# %%
X = df.drop('Rainfall', axis=1)
X
# Out:
#      Date  Location  MinTemp  MaxTemp  Evaporation  Sunshine  WindGustDir  \
# 0      59         0       90      111           15        43            7
# 1      70         0      138      130           20        75            1
# 2      81         0      135      106           27        24            7
# 3      83         0      133       42           34        69            7
# 4      84         0       86       46           26        84           10
# ..    ...       ...      ...      ...          ...       ...          ...
# 361    47         0      100      152           36        99            6
# 362    48         0       81      141           51       104            3
# 363    49         0      125       78           40        36            2
# 364    51         0      125      130           23        50            7
# 365    52         0      123      150           28       103            7
#
#      WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  Humidity3pm  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X,
                                                  y,
                                                  test_size=0.2,
                                                  shuffle=True,
                                                  random_state=40)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (262, 22) (262,)
# (66, 22) (66,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()         # 모델 구성
model.fit(X_train, y_train)        # 모델 훈련
ly_preds = model.predict(X_test)   # 예측데이터 생성
print(mean_squared_error(y_test, ly_preds))  #평가
# Out:
# 23.188135908150286

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.scatter(X_test['Sunshine'], y_test, label='y_test')
plt.scatter(X_test['Sunshine'], ly_preds, c='y', label='ly_preds')
#plt.plot(X_train, lr.predict(X_train), color='blue')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 17.877865151515156

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Sunshine'], y_test, label='y_test')
plt.scatter(X_test['Sunshine'], ry_preds, c='orange', label='ry_preds')

plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 30.575757575757574

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_test['Sunshine'], y_test, label='y_test')
plt.scatter(X_test['Sunshine'], dy_preds, c='g', label='dy_preds')
plt.show()
