# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, models

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.Flatten(),
    layers.Dropout(0,4),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(
    x_train, y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.1,
    verbose=2
)
# Out:
# Epoch 1/20
# 422/422 - 7s - 17ms/step - accuracy: 0.7480 - loss: 0.6906 - val_accuracy: 0.8242 - val_loss: 0.4789
# Epoch 2/20
# 422/422 - 2s - 4ms/step - accuracy: 0.8456 - loss: 0.4254 - val_accuracy: 0.8593 - val_loss: 0.3899
# Epoch 3/20
# 422/422 - 2s - 4ms/step - accuracy: 0.8687 - loss: 0.3623 - val_accuracy: 0.8717 - val_loss: 0.3609
# Epoch 4/20
# 422/422 - 2s - 5ms/step - accuracy: 0.8834 - loss: 0.3257 - val_accuracy: 0.8842 - val_loss: 0.3161
# Epoch 5/20
# 422/422 - 2s - 4ms/step - accuracy: 0.8914 - loss: 0.3002 - val_accuracy: 0.8880 - val_loss: 0.3065
# Epoch 6/20
# 422/422 - 2s - 4ms/step - accuracy: 0.8983 - loss: 0.2810 - val_accuracy: 0.8938 - val_loss: 0.2918
# Epoch 7/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9022 - loss: 0.2658 - val_accuracy: 0.8960 - val_loss: 0.2833
# Epoch 8/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9075 - loss: 0.2505 - val_accuracy: 0.8920 - val_loss: 0.3004
# Epoch 9/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9138 - loss: 0.2373 - val_accuracy: 0.8988 - val_loss: 0.2795
# Epoch 10/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9168 - loss: 0.2250 - val_accuracy: 0.8982 - val_loss: 0.2727
# Epoch 11/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9195 - loss: 0.2180 - val_accuracy: 0.9038 - val_loss: 0.2589
# Epoch 12/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9248 - loss: 0.2069 - val_accuracy: 0.8967 - val_loss: 0.2906
# Epoch 13/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9265 - loss: 0.1985 - val_accuracy: 0.9097 - val_loss: 0.2545
# Epoch 14/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9294 - loss: 0.1908 - val_accuracy: 0.9042 - val_loss: 0.2679
# Epoch 15/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9332 - loss: 0.1813 - val_accuracy: 0.9062 - val_loss: 0.2676
# Epoch 16/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9362 - loss: 0.1732 - val_accuracy: 0.9062 - val_loss: 0.2736
# Epoch 17/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9382 - loss: 0.1670 - val_accuracy: 0.9113 - val_loss: 0.2516
# Epoch 18/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9414 - loss: 0.1587 - val_accuracy: 0.9118 - val_loss: 0.2634
# Epoch 19/20
# 422/422 - 2s - 6ms/step - accuracy: 0.9442 - loss: 0.1528 - val_accuracy: 0.9037 - val_loss: 0.2760
# Epoch 20/20
# 422/422 - 2s - 4ms/step - accuracy: 0.9468 - loss: 0.1456 - val_accuracy: 0.9107 - val_loss: 0.2667

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\n✅ Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 2s - 7ms/step - accuracy: 0.9081 - loss: 0.2839
#
# ✅ Test Accuracy: 0.9081

# %%
predictions = model.predict(x_test[:5])
print("예측 결과:", np.argmax(predictions, axis=1))
print("실제 레이블:", y_test[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# 예측 결과: [9 2 1 1 6]
# 실제 레이블: [9 2 1 1 6]

# %%
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=128,
    validation_split=0.1,
    verbose=2
)
# Out:
# Epoch 1/5
# 422/422 - 2s - 4ms/step - accuracy: 0.9600 - loss: 0.1072 - val_accuracy: 0.9078 - val_loss: 0.3190
# Epoch 2/5
# 422/422 - 2s - 4ms/step - accuracy: 0.9640 - loss: 0.0960 - val_accuracy: 0.9038 - val_loss: 0.3392
# Epoch 3/5
# 422/422 - 2s - 4ms/step - accuracy: 0.9656 - loss: 0.0948 - val_accuracy: 0.9100 - val_loss: 0.3350
# Epoch 4/5
# 422/422 - 2s - 4ms/step - accuracy: 0.9676 - loss: 0.0876 - val_accuracy: 0.9093 - val_loss: 0.3360
# Epoch 5/5
# 422/422 - 2s - 4ms/step - accuracy: 0.9665 - loss: 0.0872 - val_accuracy: 0.9045 - val_loss: 0.3391

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"\n✅ Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.9049 - loss: 0.3478
#
# ✅ Test Accuracy: 0.9049

# %%
predictions = model.predict(x_test[:5])
print("예측 결과:", np.argmax(predictions, axis=1))
print("실제 레이블:", y_test[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 예측 결과: [9 2 1 1 6]
# 실제 레이블: [9 2 1 1 6]
