# %%
import tensorflow as tf

from tensorflow import keras

from tensorflow.keras import layers, models


fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train / 255.0

x_test  = x_test / 255.0



print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
# Out:
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)

# %%
model_dnn = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model_dnn.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
history = model_dnn.fit(
    x_train, y_train, validation_split = 0.1, epochs = 10, batch_size = 64, verbose = 2
)
# Out:
# Epoch 1/10
# 844/844 - 8s - 9ms/step - accuracy: 0.7526 - loss: 0.6961 - val_accuracy: 0.8410 - val_loss: 0.4333
# Epoch 2/10
# 844/844 - 7s - 9ms/step - accuracy: 0.8331 - loss: 0.4804 - val_accuracy: 0.8605 - val_loss: 0.3849
# Epoch 3/10
# 844/844 - 6s - 7ms/step - accuracy: 0.8464 - loss: 0.4337 - val_accuracy: 0.8648 - val_loss: 0.3701
# Epoch 4/10
# 844/844 - 7s - 9ms/step - accuracy: 0.8572 - loss: 0.4049 - val_accuracy: 0.8678 - val_loss: 0.3539
# Epoch 5/10
# 844/844 - 6s - 7ms/step - accuracy: 0.8604 - loss: 0.3901 - val_accuracy: 0.8747 - val_loss: 0.3411
# Epoch 6/10
# 844/844 - 7s - 9ms/step - accuracy: 0.8668 - loss: 0.3741 - val_accuracy: 0.8745 - val_loss: 0.3511
# Epoch 7/10
# 844/844 - 6s - 7ms/step - accuracy: 0.8711 - loss: 0.3665 - val_accuracy: 0.8753 - val_loss: 0.3406
# Epoch 8/10
# 844/844 - 7s - 9ms/step - accuracy: 0.8722 - loss: 0.3532 - val_accuracy: 0.8747 - val_loss: 0.3262
# Epoch 9/10
# 844/844 - 6s - 7ms/step - accuracy: 0.8750 - loss: 0.3476 - val_accuracy: 0.8755 - val_loss: 0.3269
# Epoch 10/10
# 844/844 - 7s - 9ms/step - accuracy: 0.8787 - loss: 0.3393 - val_accuracy: 0.8790 - val_loss: 0.3268

# %%
test_loss, test_acc = model_dnn.evaluate(x_test, y_test, verbose=2)
print(f"DNN Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8754 - loss: 0.3501
# DNN Test Accuracy: 0.8754
